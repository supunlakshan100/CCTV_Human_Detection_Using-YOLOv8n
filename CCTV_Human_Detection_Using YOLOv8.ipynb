# %%
# !nvidia-smi
# Out:
# Wed Jan 17 17:22:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8'
# Out:
# /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 144.2ms
# Speed: 13.1ms preprocess, 144.2ms inference, 1102.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="cctv_footage.jpg"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/cctv_footage.jpg: 448x640 1 person, 1 refrigerator, 130.3ms
# Speed: 4.9ms preprocess, 130.3ms inference, 1624.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls
# Out:
#  bus.jpg   cctv_footage.jpg  'CCTV_Human_Detection_Using YOLOv8.ipynb'	 data   runs   yolov8n.pt

# %%
# %cd /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data
# Out:
# /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=50 plots=True
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3
# Out:
# /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3

# %%
# %ls
# Out:
# args.yaml                                            PR_curve.png         train_batch1.jpg
# confusion_matrix_normalized.png                      R_curve.png          train_batch2.jpg
# confusion_matrix.png                                 results.csv          val_batch0_labels.jpg
# events.out.tfevents.1705513406.a59c631b23af.17071.0  results.png          val_batch0_pred.jpg
# F1_curve.png                                         train_batch0.jpg     val_batch1_labels.jpg
# labels_correlogram.jpg                               train_batch1120.jpg  val_batch1_pred.jpg
# labels.jpg                                           train_batch1121.jpg  weights/
# P_curve.png                                          train_batch1122.jpg

# %%
# !pip install Image
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 15.0 MB/s eta 0:00:00
# ...
#   Created wheel for Image: filename=image-1.5.33-py2.py3-none-any.whl size=19482 sha256=3396f1cd96e4ca0f31e9cc47d8fbd2aab030e760abb48dbf1509f29393cdafc9
#   Stored in directory: /root/.cache/pip/wheels/70/0c/a4/7cfa53a5c6225c2db2bfec08e782b43d0f25fdae2e995b69be
# Successfully built Image
# ...

# %%
from IPython.display import Image

Image(filename='/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3/val_batch1_pred.jpg', width=600)

# %% [markdown]
# ##Validate custom model

# %%
# !yolo task=detect mode=val model="//content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3/weights/best.pt" data="/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/data.yaml"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/val/labels.cache... 56 images, 4 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:05<00:00,  1.34s/it]
#                    all         60        100      0.855      0.826      0.814      0.497
# Speed: 18.3ms preprocess, 29.0ms inference, 0.0ms loss, 18.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ##Inference with custom model

# %%
# !yolo task=detect mode=predict model="//content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/runs/detect/train3/weights/best.pt" conf=0.25 source="/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/55 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images/100.png: 576x640 1 Human, 80.0ms
# image 2/55 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images/101.png: 544x640 2 Humans, 69.1ms
# image 3/55 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images/102.png: 640x608 1 Human, 65.9ms
# image 4/55 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images/103.png: 640x640 3 Humans, 8.3ms
# image 5/55 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/data/test/images/104.png: 640x640 1 Human, 7.7ms
# ...

# %% [markdown]
# ## Get Prediction

# %%
# %cd "/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8"
# Out:
# /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/Copy of CCTV Human Detection Model.pt" show=False conf=0.5 source="/content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/Test New Images/testhuman2.png" save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/Computer Vision/CCTV_Human_Detection_Using YOLOv8/Test New Images/testhuman2.png: 448x640 1 Human, 110.7ms
# Speed: 3.1ms preprocess, 110.7ms inference, 858.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict9
# 1 label saved to runs/detect/predict9/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
